# %%
import pandas as pd

# %% [markdown]
# # Get JSON for Leaflet Maps

# %%
map_df = pd.read_csv("../../VC_Data/Aggregate_Data/aggregate_data.csv")
map_df
# Out:
#      country_code          city  funding_total_usd  funding_rounds      seed  \
# 0             ARE     Abu Dhabi           31250000               3   1250000
# 1             ARE         Dubai          617684250              63  18218000
# 2             ARG  Buenos Aires          235407920             200  14043003
# 3             ARG       Córdoba             838083               6    414863
# 4             ARG   Finca Elisa            1230000               1         0
# ...           ...           ...                ...             ...       ...
# 3680          ZAF       Midrand             100000               2         0
# 3681          ZAF      Randburg           27200000               1         0
# 3682          ZAF  Stellenbosch          306450000               3     50000
# 3683          ZAF         Tokai            2850000               1         0
# 3684          ZWE        Harare           10000000               1         0
#
# ...

# %%
map_df.to_json("Test_Data/full_table.json", orient="index")
